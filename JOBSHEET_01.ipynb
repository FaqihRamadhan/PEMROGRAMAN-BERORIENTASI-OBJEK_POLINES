# %% [markdown]
# PRAKTIKUM 1

# %%
# Tipe Data Numerik
angka_int = 10
angka_float = 3.14
angka_complex = 2 + 3j

print("Integer:", angka_int, type(angka_int))
print("Float:", angka_float, type(angka_float))
print("Complex:", angka_complex, type(angka_complex))

# Boolean & String
is_active = True
teks = "Hello, Python!"

print("Boolean:", is_active, type(is_active))
print("String:", teks, type(teks))

# Tipe Data Koleksi
daftar_angka = [1, 2, 3, 4, 5]            # List (Mutable)
koordinat = (10, 20)                      # Tuple (Immutable)
himpunan_angka = {1, 2, 3, 2, 1}          # Set (Unique)
data_mahasiswa = {                        # Dictionary (Key-Value)
    "nama": "Andi",
    "nim": "A11.2022.12345",
    "jurusan": "Teknik Informatika"
}

print("List:", daftar_angka)
print("Tuple:", koordinat)
print("Set:", himpunan_angka)
print("Dictionary:", data_mahasiswa)

# Konversi Tipe Data
nilai_str = "100"
nilai_int = int(nilai_str)
print("Konversi String ke Int:", nilai_int, type(nilai_int))
# Out:
# Integer: 10 <class 'int'>
# Float: 3.14 <class 'float'>
# Complex: (2+3j) <class 'complex'>
# Boolean: True <class 'bool'>
# String: Hello, Python! <class 'str'>
# List: [1, 2, 3, 4, 5]
# Tuple: (10, 20)
# Set: {1, 2, 3}
# Dictionary: {'nama': 'Andi', 'nim': 'A11.2022.12345', 'jurusan': 'Teknik Informatika'}
# Konversi String ke Int: 100 <class 'int'>

# %% [markdown]
# PRAKTIKUM 2

# %%
# Tipe Data Numerik
angka_int = 10
angka_float = 3.14
angka_complex = 2 + 3j

print("Integer:", angka_int, type(angka_int))
print("Float:", angka_float, type(angka_float))
print("Complex:", angka_complex, type(angka_complex))

# Boolean & String
is_active = True
teks = "Hello, Python!"

print("Boolean:", is_active, type(is_active))
print("String:", teks, type(teks))

# Tipe Data Koleksi
daftar_angka = [1, 2, 3, 4, 5]            # List (Mutable)
koordinat = (10, 20)                      # Tuple (Immutable)
himpunan_angka = {1, 2, 3, 2, 1}          # Set (Unique)
data_mahasiswa = {                        # Dictionary (Key-Value)
    "nama": "Andi",
    "nim": "A11.2022.12345",
    "jurusan": "Teknik Informatika"
}

print("List:", daftar_angka)
print("Tuple:", koordinat)
print("Set:", himpunan_angka)
print("Dictionary:", data_mahasiswa)

# Konversi Tipe Data
nilai_str = "100"
nilai_int = int(nilai_str)
print("Konversi String ke Int:", nilai_int, type(nilai_int))
# Out:
# Integer: 10 <class 'int'>
# Float: 3.14 <class 'float'>
# Complex: (2+3j) <class 'complex'>
# Boolean: True <class 'bool'>
# String: Hello, Python! <class 'str'>
# List: [1, 2, 3, 4, 5]
# Tuple: (10, 20)
# Set: {1, 2, 3}
# Dictionary: {'nama': 'Andi', 'nim': 'A11.2022.12345', 'jurusan': 'Teknik Informatika'}
# Konversi String ke Int: 100 <class 'int'>

# %% [markdown]
# PRAKTIKUM 3
